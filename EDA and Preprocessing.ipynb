# %% [markdown]
# ### Data - Summary

# %%
# Packages
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib 
# %matplotlib inline
plt.style.use('ggplot')

from copy import deepcopy
import warnings
warnings.filterwarnings('ignore')

# %%
csv = pd.read_csv("accepted_2007_to_2018Q4.csv")
accept = csv.copy()

# %%
csv.shape
# Out:
# (2260701, 151)

# %%
accept.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %% [markdown]
# * Loan status "Current", "Does not meet the credit policy. Status:Fully Paid ", and "Does not meet the credit policy. Status:Charged Off" removed
# * current doesn't procide any good insight of weather the borrower going to default and the other two, there is no pubilcly Available info
# * There's a group of oberv with nans completely - remove

# %%
# 0 for default, 1 for not default
accept["default"] = np.where(accept["loan_status"].isin(["Charged Off", "Default"]),0, 1)
accept.drop(["loan_status"], axis = 1, inplace = True)

# %%
# loan status barplot
explode = (0.1,1) 
data = accept["default"].value_counts(normalize = True, dropna = False).unique()
labels = ["Not Default", "Default"]
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.pie(data, explode=explode, labels=labels, autopct='%.2f%%',
        shadow= True, 
        startangle=10)
ax1.legend(labels)
ax1.set(aspect="equal", title='Loan Status')
# plt.savefig("Loan default.png")
plt.show()

# Imbalance - upsample

# %%
# Application Type, grade, amount, interest rate

# Create a scatter plot of age and interest rate
plt.figure(figsize=(8,6))
colors = ["blue","red"] # 0, 1
plt.scatter(accept["loan_amnt"], accept["int_rate"],
            c = accept['default'],
            cmap = matplotlib.colors.ListedColormap(colors),
            alpha=0.5)
plt.xlabel("Loan Amount")
plt.ylabel("Loan Interest Rate")
plt.savefig("1.png")
plt.show()
# Default with higher interest, a few with high dti

# %%
ax = sns.boxplot(x="grade", y="int_rate", hue="default",
                 data=accept, palette="Set3")
plt.savefig("2.png")

# %%
# Application Type, grade, amount, interest rate

# Create a scatter plot of age and interest rate
plt.figure(figsize=(8,6))
colors = ["blue","red"]
plt.scatter(accept["int_rate"], accept["dti"],
            c = accept['default'],
            cmap = matplotlib.colors.ListedColormap(colors),
            alpha=0.5)
plt.xlabel("interest rate")
plt.ylabel("dti")
plt.savefig("3.png")
plt.show()
# Default with higher interest, a few with high dti

# %%
# ax = sns.swarmplot(x="grade", y="loan_amnt", hue="default",
#                    data=accept, palette="Set2", dodge=True)

ax = sns.boxplot(x="grade", y="annual_inc", hue="default",
                 data=accept, palette="Set3")
plt.savefig("4.png")

# %%
ax = sns.boxplot(x="annual_inc", y="grade", hue="default",
                 data=accept, palette="Set3")

# %%
accept.boxplot(column = ["annual_inc"], by = ["grade"])
# Out:
# <AxesSubplot:title={'center':'annual_inc'}, xlabel='[grade]'>

# %%
# purpose, grade, 
pd.crosstab(accept["grade"], accept["default"], values =accept["dti"], aggfunc="mean" )
# Out:
# default          0          1
# grade
# A        17.116156  16.208865
# B        18.374213  17.931537
# C        19.921389  19.495974
# D        21.163869  20.875343
# E        21.877963  21.430454
# F        22.057842  21.474470
# G        22.298911  22.513139

# %%
pd.crosstab(accept["purpose"], accept["default"], values =accept["annual_inc"], aggfunc="mean" )
# Out:
# default                        0             1
# purpose
# car                 62382.614883  70992.800287
# credit_card         69166.184708  78882.299628
# debt_consolidation  69655.951628  77952.307605
# educational         51711.803571  51214.493424
# home_improvement    83249.268998  93552.147413
# house               73808.047764  85887.334962
# major_purchase      73410.152460  80303.906787
# medical             70492.738395  74075.127169
# moving              61684.224210  71804.343184
# other               66122.665765  73780.952985
# renewable_energy    66402.196154  75122.520523
# small_business      88567.592980  95203.729177
# vacation            64393.107750  70499.363439
# wedding             67271.083441  69859.782558

# %% [markdown]
# ### Data Cleaning - Outlier, Missing, conversion

# %%
# Inrelvent Status 
status_drop = ["Current", "Does not meet the credit policy. Status:Fully Paid", "Does not meet the credit policy. Status:Charged Off"]
for i in status_drop:
    i_obsev = csv[csv.loan_status == i].index
    accept.drop(i_obsev, axis = 0, inplace = True)

# %%
# There's a number of obv
emp_obve = accept[accept["term"].isna()].index
accept.drop(emp_obve, axis = 0, inplace = True)

# %%
# Removing columns with missing over 75%, # Misssingness - over 75% imputation might casue Inaccuracy.
keep = accept.columns[accept.isnull().mean() <= 0.25]
accept = accept[keep]

# %%
# Irrelevant Features
accept.drop(["id","url", "last_pymnt_d", "last_credit_pull_d","earliest_cr_line", ], axis = 1, inplace = True)

# %%
# Outlier Removing
Outlier = ["total_rev_hi_lim", "tot_hi_cred_lim", "dti"]
Outlier_obv = accept[accept["tot_hi_cred_lim"] > 5915440].index.to_list() + accept[accept["dti"] < 0].index.to_list()
accept.drop(Outlier_obv, axis = 0, inplace = True)

# %%
# Categorical type handling 
accept["term"] = accept["term"].str.replace("months", "").astype(dtype = "str")
accept["issue_d"] = pd.to_datetime(accept["issue_d"])
accept["issue_d_year"] = accept["issue_d"].dt.year
accept["issue_d_month"] = accept["issue_d"].dt.month
accept.drop("issue_d",axis = 1, inplace = True)
accept["emp_length"] = accept["emp_length"].fillna("0").str.strip("+ years").str.replace("< 1", "0").astype("int")

# %%
# Imputation Method
def Imputation(data):
    num = data.select_dtypes(exclude = "object").columns 
    cat = data.select_dtypes(include = "object").columns
    for i in num:
        data[i] = data[i].fillna(0)
    for i in cat:
        data[i] = data[i].fillna("None")
    return data

# %%
# Imputation
dImputation(accept)
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           3600.0       3600.0           3600.0   36      13.99       123.03
# 1          24700.0      24700.0          24700.0   36      11.99       820.28
# 2          20000.0      20000.0          20000.0   60      10.78       432.66
# 4          10400.0      10400.0          10400.0   60      22.45       289.91
# 5          11950.0      11950.0          11950.0   36      13.44       405.18
# ...            ...          ...              ...   ...       ...          ...
# 2260688    18000.0      18000.0          18000.0   60       9.49       377.95
# 2260690    29400.0      29400.0          29400.0   60      13.99       683.94
# 2260691    32000.0      32000.0          32000.0   60      14.49       752.74
# 2260692    16000.0      16000.0          16000.0   60      12.79       362.34
# 2260697    24000.0      24000.0          24000.0   60      14.49       564.56
#
# ...

# %%
accept.isnull().sum().head()
# Out:
# id                 0
# loan_amnt          0
# funded_amnt        0
# funded_amnt_inv    0
# term               0
# dtype: int64

# %%
# Sampling from the dataset using just 10% of the data
size = round(accept.shape[0]*0.1)
data = accept.sample(n = size, axis = 0, random_state = 42)
print(accept.shape, data.shape)
# Out:
# (1379586, 100) (137959, 100)

# %%
# Save the as CSV
# data.to_csv("data.csv")

# %% [markdown]
# ### Note
# Any rational explanation on why the interest rate should be grade/sub-grade dependent?
#
# The interest rates take into account of credit risk and market conditions and the final interet rate for each loan grade is calculated by the following equation: Lending Club Base Rate + Adjustment for Risk & Volatility
#
# Where the "Adjustment for Risk & Volatility" is designed to cover expected losses and provide higher risk-adjusted returns for each loan grade increment from A1 to G5.
#
# The loan grade is the result of a formula that takes into account not only credit score, but also a combination of several indicators of credit risk from the credit report and loan application
#
# Any rational explanation on the time series variations of interest rates?
#
# Financial indesutry faces seasonality, where the basic seasonal pattern of the banking industry follows
#
# a period of annual lows in late January and February,
# a surge in loans that begins in March
# rises sharply through May, usually peaking in early June
# From there, demand for banking services typically remains relatively flat to slightly down through the summer months, extends to around the first of October
# Then, a steady increase in business from the first part of October through the first part of January
# Interest rates tend to be lower in spring and fall, and higher in winter and summer, and corporations obviously try to obtain major financing when rates are lowest. Spring is historically the prime home buying season. This leads to a sharp increase in applications for home mortgages during March, April and May.
#
# A third factor that drives the seasonal pattern for the banking industry is the increased demand for investment services that occurs in December and the first part of January. This is the time of year when portfolio and fund managers do a lot of rebalancing and when individuals make significant investment adjustments, such as end-of-the-year or first-of-the-year moves designed to gain tax advantages.
#
# Tax planning is also a factor in the demand for bank services and can be a factor contributing to the seasonal rise in activity that begins in March, just prior to the April 15th income tax deadline.
#
# Any rational explanation why the interest rate rise w.r.t. loan term?
#
# With a longer duration (loan term) comes a higher risk that the loan will not be repaid, which generally explains why long-term rates are higher than short-term ones, in addition to the overall capacity for customers to take on debt
# For investors, it is crucial to know whether a loan is served to completion (loan_status 'Fully Paid'). Please analyze the percentages of non-completed loans in each loan grade/subgrade (i.e. default, charged off) which go beyond delinquency.
